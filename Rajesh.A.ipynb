# %%
import pandas as pd
df=pd.read_excel(r"file:///C:/Users/SysAdmin/Documents/INTERNSHIP%20(DATA%20ANALYSTICS)/uber%20project/Rajesh.A%20Uber%20Project.xlsx")
df.head()
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], dayfirst=True, errors='coerce')
df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], dayfirst=True, errors='coerce')
df['Hour'] = df['Request timestamp'].dt.hour
df['Date'] = df['Request timestamp'].dt.date
df['Hour'].value_counts().sort_index().plot(kind='bar', title='Requests per Hour')
df['Status'].value_counts().plot(kind='bar', title='Status Distribution')
gap = df[df['Status'].isin(['Cancelled', 'No Cars Available'])]
gap['Pickup point'].value_counts().plot(kind='bar', title='Demand Gaps by Pickup Point')
df['Date'].value_counts().sort_index().plot(kind='line', title='Requests per Day')
# Out:
# <Axes: title={'center': 'Requests per Day'}, xlabel='Date'>

# %%
import pandas as pd
df=pd.read_csv(r"file:///C:/Users/SysAdmin/Documents/INTERNSHIP%20(DATA%20ANALYSTICS)/uber%20project/Rajesh.A%20Uber Project.csv")
df.head()
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], dayfirst=True, errors='coerce')
df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], dayfirst=True, errors='coerce')
df['Hour'] = df['Request timestamp'].dt.hour
df['Date'] = df['Request timestamp'].dt.date
df['Hour'].value_counts().sort_index().plot(kind='bar', title='Requests per Hour')
# Out:
# C:\Users\SysAdmin\AppData\Local\Temp\ipykernel_22772\4008555072.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], dayfirst=True, errors='coerce')
# C:\Users\SysAdmin\AppData\Local\Temp\ipykernel_22772\4008555072.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], dayfirst=True, errors='coerce')
# <Axes: title={'center': 'Requests per Hour'}, xlabel='Hour'>

# %%
import pandas as pd
df=pd.read_csv(r"file:///C:/Users/SysAdmin/Documents/INTERNSHIP%20(DATA%20ANALYSTICS)/uber%20project/Rajesh.A%20Uber Project.csv")
df.head()
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], dayfirst=True, errors='coerce')
df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], dayfirst=True, errors='coerce')
df['Hour'] = df['Request timestamp'].dt.hour
df['Date'] = df['Request timestamp'].dt.date
df['Hour'].value_counts().sort_index().plot(kind='bar', title='Requests per Hour')
df['Status'].value_counts().plot(kind='bar', title='Status Distribution')
# Out:
# C:\Users\SysAdmin\AppData\Local\Temp\ipykernel_22772\2300272170.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], dayfirst=True, errors='coerce')
# C:\Users\SysAdmin\AppData\Local\Temp\ipykernel_22772\2300272170.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], dayfirst=True, errors='coerce')
# <Axes: title={'center': 'Status Distribution'}, xlabel='Status'>
